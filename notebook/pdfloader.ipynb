# %%
##pdf loading
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader
from langchain_community.document_loaders import DirectoryLoader

# %%
print("Hello world")
# Out:
# Hello world

# %%
dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", ## Pattern to match files  
    loader_cls= PyMuPDFLoader, ##loader class to use
    show_progress=False

)

pdf_documents=dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'file_path': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'format': 'PDF 1.7', 'title': '', 'author': 'Aarzu Hooda', 'subject': '', 'keywords': '', 'moddate': '2025-09-08T13:55:43+05:30', 'trapped': '', 'modDate': "D:20250908135543+05'30'", 'creationDate': "D:20250908135543+05'30'", 'page': 0}, page_content='1 \n \n \n \n \n \n \n \n \n \nComparison of NRZ and RZ Modulation in WDM Optical \nSystems Using Eye Diagrams and CNN Classification \n \nType of project: Software \n \n \n \n \n \n \nStudents’ Signatures \n         Supervisor Signature \nDate: \n          Date:'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'file_path': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'format': 'PDF 1.7', 'title': '', 'author': 'Aarzu Hooda', 'subject': '', 'keywords': '', 'moddate': '2025-09-08T13:55:43+05:30', 'trapped': '', 'modDate': "D:20250908135543+05'30'", 'creationDate': "D:20250908135543+05'30'", 'page': 1}, page_content='2 \n \n \n1. TEAM DETAILS \n \n2. TITLE & BROAD AREA OF PROJECT \nComparison of NRZ and RZ Modulation in WDM Optical Systems Using Eye \nDiagrams and CNN Classification \nType of project: Software \n \nThis research investigates the design and performance analysis of a WDM system employing \na Mach–Zehnder Modulator, with specific focus on Return-to-Zero (RZ) and Non-Return-to-\nZero (NRZ) modulation formats. A dual-approach methodology is adopted: regression models \nare used to quantitatively predict critical performance parameters (Optical Signal-to-Noise \nRatio (OSNR), Bit Error Rate (BER), and Q-Factor) based on system configurations, while \nConvolutional Neural Networks (CNNs) are employed to classify and interpret eye diagrams, \noffering a data-driven understanding of signal integrity and modulation quality. \n3. OBJECTIVES OF THE PROJECT \n1. To design and simulate a Wavelength Division Multiplexing (WDM) system using a \nMach–Zehnder Modulator (MZM) \n2. To analyse and compare the performance of Return-to-Zero (RZ) and Non-Return-to-\nZero (NRZ) modulation schemes within the WDM framework and collect data for \nmodel training \n3. To implement regression models for predicting key performance metrics such as Eye \nHeight, BER, and Q-Factor \n4. To apply Convolutional Neural Networks (CNNs) for classification and analysis of \neye diagrams, enabling intelligent signal quality assessment \n \nSr. No. \nTeam Member \nSID \nSupervisor \n1. \nSwastik Kalsi  \n23105129 \nProf. Jasbir Kaur \n(ECE Dept.) \n \n2. \nDivyanshu Sati  \n23105103 \n3. \nSidharth \n23105018'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'file_path': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'format': 'PDF 1.7', 'title': '', 'author': 'Aarzu Hooda', 'subject': '', 'keywords': '', 'moddate': '2025-09-08T13:55:43+05:30', 'trapped': '', 'modDate': "D:20250908135543+05'30'", 'creationDate': "D:20250908135543+05'30'", 'page': 2}, page_content='3 \n \n4. PROPOSED METHODOLOGY & WORKFLOW \n4.1 System Simulation (OptiSystem): \no \nA WDM system is designed using a Mach–Zehnder Modulator (MZM) for high-speed optical \ncommunication. \no \nMultiple channels (four) are transmitted over a single optical fibre (1550 nm) , incorporating PRBS \ndata, RZ/NRZ modulation, and realistic impairments (noise, dispersion, non-linearities). \n4.2 Data Collection: \no \nPerformance metrics (Q-Factor, BER, decision threshold, and eye height) are recorded at 2 km intervals \nfrom 1 km to 100 km. \no \nEye diagram images are collected at 5 km intervals to capture signal quality variations. \n4.3 Regression Modelling: \no \nMachine learning regression models (Linear, Ridge, Lasso, Random Forest, XGBoost, and MLP \nRegressor) are trained to predict Q-Factor, BER, and related metrics. \no \nThis enables quick estimation of performance without full simulations. \n4.4 CNN-Based Eye Diagram Analysis: \no \nCollected eye diagrams are used to train a Convolutional Neural Network (CNN). \no \nThe CNN classifies signal quality, detecting eye closure, jitter, and noise. \no \nProvides intelligent quality assessment to complement OSNR, BER, and Q-Factor analysis. \n4.5 Workflow: \no \nSimulation → Data Extraction → Regression Model Training → Eye Diagram Collection → CNN \nTraining → Performance Comparison → Final Evaluation. \n5. SOFTWARE & HARDWARE REQUIREMENTS \n5.1  Software Requirements \n• \nOptiSystem – For simulation of WDM system, PRBS data generation, modulation (RZ/NRZ), and \nfiber channel modelling. \n• \nPython (VS Code or Google Colab) – For data preprocessing, regression modelling, and CNN \nimplementation. \no \nLibraries: Scikit-learn (Linear, Ridge, Lasso, RF, XGBoost, MLP), TensorFlow/Keras or \nPyTorch (for CNN), Pandas, NumPy, Matplotlib. \n• \nMS Excel / CSV tools – For dataset organization and intermediate analysis. \n5.2  Hardware Requirements \n• \nProcessor: AMD Ryzen 7 or higher (multi-core recommended). \n• \nRAM: Minimum 8 GB (16 GB preferred for faster simulations and ML training). \n• \nStorage: 20 GB free space (for OptiSystem projects, datasets, and ML models). \n• \nGPU: NVIDIA GPU with CUDA support for CNN training and image processing. \n• \nOperating System: Windows 11'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'file_path': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'format': 'PDF 1.7', 'title': '', 'author': 'Aarzu Hooda', 'subject': '', 'keywords': '', 'moddate': '2025-09-08T13:55:43+05:30', 'trapped': '', 'modDate': "D:20250908135543+05'30'", 'creationDate': "D:20250908135543+05'30'", 'page': 3}, page_content='4 \n \n6. TIMELINE & MILESTONES')]

# %%
import os
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from pathlib import Path

# %%
### Read all the pdf's inside the directory
def process_all_pdfs(pdf_directory):
    """Process all PDF files in a directory"""
    all_documents = []
    pdf_dir = Path(pdf_directory)
    
    # Find all PDF files recursively
    pdf_files = list(pdf_dir.glob("**/*.pdf"))
    
    print(f"Found {len(pdf_files)} PDF files to process")
    
    for pdf_file in pdf_files:
        print(f"\nProcessing: {pdf_file.name}")
        try:
            loader = PyPDFLoader(str(pdf_file))
            documents = loader.load()
            
            # Add source information to metadata
            for doc in documents:
                doc.metadata['source_file'] = pdf_file.name
                doc.metadata['file_type'] = 'pdf'
            
            all_documents.extend(documents)
            print(f"  ✓ Loaded {len(documents)} pages")
            
        except Exception as e:
            print(f"  ✗ Error: {e}")
    
    print(f"\nTotal documents loaded: {len(all_documents)}")
    return all_documents

# Process all PDFs in the data directory
all_pdf_documents = process_all_pdfs("../data")
# Out:
# Found 1 PDF files to process
#
# Processing: Synopsis.pdf
#   ✓ Loaded 4 pages
#
# Total documents loaded: 4

# %%
## Text splitiing into chunks

def split_documents(documents,chunk_size=100,chunk_overlap=20):
    """Split documents into smaller chunks for better RAG performance"""
    text_splitter=RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        length_function=len,
        separators=["\n\n", "\n", " ", ""]

    )

    split_docs = text_splitter.split_documents(documents)
    print(f"Split {len(documents)} documents into {len(split_docs)} chunks")
    
    # Show example of a chunk
    if split_docs:
        print(f"\nExample chunk:")
        print(f"Content: {split_docs[0].page_content[:200]}...")
        print(f"Metadata: {split_docs[0].metadata}")
    
    return split_docs

# %%
chunks=split_documents(all_pdf_documents)
chunks
# Out:
# Split 4 documents into 60 chunks
#
# Example chunk:
# Content: 1
#
#
#
#
#
#
#
#
#
# Comparison of NRZ and RZ Modulation in WDM Optical...
# Metadata: {'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 0, 'page_label': '1', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}
# [Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 0, 'page_label': '1', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='1 \n \n \n \n \n \n \n \n \n \nComparison of NRZ and RZ Modulation in WDM Optical'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 0, 'page_label': '1', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='Systems Using Eye Diagrams and CNN Classification \n \nType of project: Software'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 0, 'page_label': '1', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='Students’ Signatures          Supervisor Signature \nDate:           Date:'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='2 \n \n \n1. TEAM DETAILS \n \n2. TITLE & BROAD AREA OF PROJECT'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='Comparison of NRZ and RZ Modulation in WDM Optical Systems Using Eye'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='Diagrams and CNN Classification \nType of project: Software'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='This research investigates the design and performance analysis of a WDM system employing'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='a Mach–Zehnder Modulator, with specific focus on Return -to-Zero (RZ) and Non-Return-to-'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='Zero (NRZ) modulation formats. A dual-approach methodology is adopted: regression models'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='are used to quantitatively predict critical performance parameters  (Optical Signal -to-Noise'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='Ratio (OSNR), Bit Error Rate (BER), and Q -Factor) based on system configurations, while'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='Convolutional Neural Networks (CNNs) are employed to classify and i nterpret eye diagrams,'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='offering a data-driven understanding of signal integrity and modulation quality.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='3. OBJECTIVES OF THE PROJECT'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='1. To design and simulate a Wavelength Division Multiplexing (WDM) system using a'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='Mach–Zehnder Modulator (MZM)'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='2. To analyse and compare the performance of Return-to-Zero (RZ) and Non-Return-to-'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='Zero (NRZ) modulation schemes within the WDM framework and collect data for \nmodel training'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='3. To implement regression models for predicting key performance metrics such as Eye'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='Height, BER, and Q-Factor'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='4. To apply Convolutional Neural Networks (CNNs) for classification and analysis of'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='eye diagrams, enabling intelligent signal quality assessment \n \nSr. No. Team Member SID Supervisor'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='1. Swastik Kalsi  23105129 Prof. Jasbir Kaur \n(ECE Dept.) \n \n2. Divyanshu Sati  23105103'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='3. Sidharth 23105018'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='3 \n \n4. PROPOSED METHODOLOGY & WORKFLOW \n4.1 System Simulation (OptiSystem):'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='o A WDM system is designed using a Mach–Zehnder Modulator (MZM) for high-speed optical'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='communication.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='o Multiple channels (four) are transmitted over a single optical fibre (1550 nm) , incorporating'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='nm) , incorporating PRBS'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='data, RZ/NRZ modulation, and realistic impairments (noise, dispersion, non -linearities).'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='4.2 Data Collection:'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='o Performance metrics (Q-Factor, BER, decision threshold, and eye height) are recorded at 2 km'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='recorded at 2 km intervals'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='from 1 km to 100 km.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='o Eye diagram images are collected at 5 km intervals to capture signal quality variations.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='4.3 Regression Modelling:'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='o Machine learning regression models (Linear, Ridge, Lasso, Random Forest, XGBoost, and MLP'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='Regressor) are trained to predict Q-Factor, BER, and related metrics.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='o This enables quick estimation of performance without full simulations.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='4.4 CNN-Based Eye Diagram Analysis:'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='o Collected eye diagrams are used to train a Convolutional Neural Network (CNN).'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='o The CNN classifies signal quality, detecting eye closure, jitter, and noise.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='o Provides intelligent quality assessment to complement OSNR, BER, and Q-Factor analysis.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='4.5 Workflow:'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='o Simulation → Data Extraction → Regression Model Training → Eye Diagram Collection → CNN'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='Training → Performance Comparison → Final Evaluation. \n5. SOFTWARE & HARDWARE REQUIREMENTS'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='5.1  Software Requirements'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='• OptiSystem – For simulation of WDM system, PRBS data generation, modulation (RZ/NRZ), and'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='fiber channel modelling.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='• Python (VS Code or Google Colab) – For data preprocessing, regression modelling, and CNN'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='implementation.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='o Libraries: Scikit-learn (Linear, Ridge, Lasso, RF, XGBoost, MLP), TensorFlow/Keras or'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='PyTorch (for CNN), Pandas, NumPy, Matplotlib.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='• MS Excel / CSV tools – For dataset organization and intermediate analysis.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='5.2  Hardware Requirements \n• Processor: AMD Ryzen 7 or higher (multi-core recommended).'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='• RAM: Minimum 8 GB (16 GB preferred for faster simulations and ML training).'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='• Storage: 20 GB free space (for OptiSystem projects, datasets, and ML models).'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='• GPU: NVIDIA GPU with CUDA support for CNN training and image processing.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='• Operating System: Windows 11'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 3, 'page_label': '4', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='4 \n \n6. TIMELINE & MILESTONES')]

# %% [markdown]
# embedded and vector db

# %%
import os

# %%
import numpy as np
from sentence_transformers import SentenceTransformer
import chromadb
from chromadb.config import Settings
import uuid
from typing import List, Dict, Any, Tuple
from sklearn.metrics.pairwise import cosine_similarity

# %%
class EmbeddingManager:
    """Handles document embedding generation using SentenceTransformer"""
    
    def __init__(self, model_name: str = "all-MiniLM-L6-v2"):
        """
        Initialize the embedding manager
        
        Args:
            model_name: HuggingFace model name for sentence embeddings
        """
        self.model_name = model_name
        self.model = None
        self._load_model()

    def _load_model(self):
        """Load the SentenceTransformer model"""
        try:
            print(f"Loading embedding model: {self.model_name}")
            self.model = SentenceTransformer(self.model_name)
            print(f"Model loaded successfully. Embedding dimension: {self.model.get_sentence_embedding_dimension()}")
        except Exception as e:
            print(f"Error loading model {self.model_name}: {e}")
            raise

    def generate_embeddings(self, texts: List[str]) -> np.ndarray:
        """
        Generate embeddings for a list of texts
        
        Args:
            texts: List of text strings to embed
            
        Returns:
            numpy array of embeddings with shape (len(texts), embedding_dim)
        """
        if not self.model:
            raise ValueError("Model not loaded")
        
        print(f"Generating embeddings for {len(texts)} texts...")
        embeddings = self.model.encode(texts, show_progress_bar=True)
        print(f"Generated embeddings with shape: {embeddings.shape}")
        return embeddings


## initialize the embedding manager

embedding_manager=EmbeddingManager()
embedding_manager
# Out:
# Loading embedding model: all-MiniLM-L6-v2
# Model loaded successfully. Embedding dimension: 384

# %% [markdown]
# vector db

# %%
class VectorStore:
    """Manages document embeddings in a ChromaDB vector store"""
    
    def __init__(self, collection_name: str = "pdf_documents", persist_directory: str = "../data/vector_store"):
        """
        Initialize the vector store
        
        Args:
            collection_name: Name of the ChromaDB collection
            persist_directory: Directory to persist the vector store
        """
        self.collection_name = collection_name
        self.persist_directory = persist_directory
        self.client = None
        self.collection = None
        self._initialize_store()

    def _initialize_store(self):
        """Initialize ChromaDB client and collection"""
        try:
            # Create persistent ChromaDB client
            os.makedirs(self.persist_directory, exist_ok=True)
            self.client = chromadb.PersistentClient(path=self.persist_directory)
            
            # Get or create collection
            self.collection = self.client.get_or_create_collection(
                name=self.collection_name,
                metadata={"description": "PDF document embeddings for RAG"}
            )
            print(f"Vector store initialized. Collection: {self.collection_name}")
            print(f"Existing documents in collection: {self.collection.count()}")
            
        except Exception as e:
            print(f"Error initializing vector store: {e}")
            raise

    def add_documents(self, documents: List[Any], embeddings: np.ndarray):
        """
        Add documents and their embeddings to the vector store
        
        Args:
            documents: List of LangChain documents
            embeddings: Corresponding embeddings for the documents
        """
        if len(documents) != len(embeddings):
            raise ValueError("Number of documents must match number of embeddings")
        
        print(f"Adding {len(documents)} documents to vector store...")
        
        # Prepare data for ChromaDB
        ids = []
        metadatas = []
        documents_text = []
        embeddings_list = []
        
        for i, (doc, embedding) in enumerate(zip(documents, embeddings)):
            # Generate unique ID
            doc_id = f"doc_{uuid.uuid4().hex[:8]}_{i}"
            ids.append(doc_id)
            
            # Prepare metadata
            metadata = dict(doc.metadata)
            metadata['doc_index'] = i
            metadata['content_length'] = len(doc.page_content)
            metadatas.append(metadata)
            
            # Document content
            documents_text.append(doc.page_content)
            
            # Embedding
            embeddings_list.append(embedding.tolist())
        
        # Add to collection
        try:
            self.collection.add(
                ids=ids,
                embeddings=embeddings_list,
                metadatas=metadatas,
                documents=documents_text
            )
            print(f"Successfully added {len(documents)} documents to vector store")
            print(f"Total documents in collection: {self.collection.count()}")
            
        except Exception as e:
            print(f"Error adding documents to vector store: {e}")
            raise

vectorstore=VectorStore()
vectorstore
# Out:
# Vector store initialized. Collection: pdf_documents
# Existing documents in collection: 0

# %%
chunks
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 0, 'page_label': '1', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='1 \n \n \n \n \n \n \n \n \n \nComparison of NRZ and RZ Modulation in WDM Optical'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 0, 'page_label': '1', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='Systems Using Eye Diagrams and CNN Classification \n \nType of project: Software'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 0, 'page_label': '1', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='Students’ Signatures          Supervisor Signature \nDate:           Date:'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='2 \n \n \n1. TEAM DETAILS \n \n2. TITLE & BROAD AREA OF PROJECT'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='Comparison of NRZ and RZ Modulation in WDM Optical Systems Using Eye'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='Diagrams and CNN Classification \nType of project: Software'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='This research investigates the design and performance analysis of a WDM system employing'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='a Mach–Zehnder Modulator, with specific focus on Return -to-Zero (RZ) and Non-Return-to-'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='Zero (NRZ) modulation formats. A dual-approach methodology is adopted: regression models'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='are used to quantitatively predict critical performance parameters  (Optical Signal -to-Noise'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='Ratio (OSNR), Bit Error Rate (BER), and Q -Factor) based on system configurations, while'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='Convolutional Neural Networks (CNNs) are employed to classify and i nterpret eye diagrams,'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='offering a data-driven understanding of signal integrity and modulation quality.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='3. OBJECTIVES OF THE PROJECT'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='1. To design and simulate a Wavelength Division Multiplexing (WDM) system using a'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='Mach–Zehnder Modulator (MZM)'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='2. To analyse and compare the performance of Return-to-Zero (RZ) and Non-Return-to-'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='Zero (NRZ) modulation schemes within the WDM framework and collect data for \nmodel training'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='3. To implement regression models for predicting key performance metrics such as Eye'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='Height, BER, and Q-Factor'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='4. To apply Convolutional Neural Networks (CNNs) for classification and analysis of'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='eye diagrams, enabling intelligent signal quality assessment \n \nSr. No. Team Member SID Supervisor'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='1. Swastik Kalsi  23105129 Prof. Jasbir Kaur \n(ECE Dept.) \n \n2. Divyanshu Sati  23105103'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 1, 'page_label': '2', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='3. Sidharth 23105018'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='3 \n \n4. PROPOSED METHODOLOGY & WORKFLOW \n4.1 System Simulation (OptiSystem):'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='o A WDM system is designed using a Mach–Zehnder Modulator (MZM) for high-speed optical'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='communication.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='o Multiple channels (four) are transmitted over a single optical fibre (1550 nm) , incorporating'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='nm) , incorporating PRBS'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='data, RZ/NRZ modulation, and realistic impairments (noise, dispersion, non -linearities).'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='4.2 Data Collection:'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='o Performance metrics (Q-Factor, BER, decision threshold, and eye height) are recorded at 2 km'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='recorded at 2 km intervals'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='from 1 km to 100 km.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='o Eye diagram images are collected at 5 km intervals to capture signal quality variations.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='4.3 Regression Modelling:'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='o Machine learning regression models (Linear, Ridge, Lasso, Random Forest, XGBoost, and MLP'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='Regressor) are trained to predict Q-Factor, BER, and related metrics.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='o This enables quick estimation of performance without full simulations.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='4.4 CNN-Based Eye Diagram Analysis:'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='o Collected eye diagrams are used to train a Convolutional Neural Network (CNN).'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='o The CNN classifies signal quality, detecting eye closure, jitter, and noise.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='o Provides intelligent quality assessment to complement OSNR, BER, and Q-Factor analysis.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='4.5 Workflow:'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='o Simulation → Data Extraction → Regression Model Training → Eye Diagram Collection → CNN'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='Training → Performance Comparison → Final Evaluation. \n5. SOFTWARE & HARDWARE REQUIREMENTS'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='5.1  Software Requirements'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='• OptiSystem – For simulation of WDM system, PRBS data generation, modulation (RZ/NRZ), and'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='fiber channel modelling.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='• Python (VS Code or Google Colab) – For data preprocessing, regression modelling, and CNN'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='implementation.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='o Libraries: Scikit-learn (Linear, Ridge, Lasso, RF, XGBoost, MLP), TensorFlow/Keras or'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='PyTorch (for CNN), Pandas, NumPy, Matplotlib.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='• MS Excel / CSV tools – For dataset organization and intermediate analysis.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='5.2  Hardware Requirements \n• Processor: AMD Ryzen 7 or higher (multi-core recommended).'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='• RAM: Minimum 8 GB (16 GB preferred for faster simulations and ML training).'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='• Storage: 20 GB free space (for OptiSystem projects, datasets, and ML models).'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='• GPU: NVIDIA GPU with CUDA support for CNN training and image processing.'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 2, 'page_label': '3', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='• Operating System: Windows 11'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-09-08T13:55:43+05:30', 'author': 'Aarzu Hooda', 'moddate': '2025-09-08T13:55:43+05:30', 'source': '..\\data\\pdf\\Synopsis.pdf', 'total_pages': 4, 'page': 3, 'page_label': '4', 'source_file': 'Synopsis.pdf', 'file_type': 'pdf'}, page_content='4 \n \n6. TIMELINE & MILESTONES')]

# %%
### Convert the text to embeddings
texts=[doc.page_content for doc in chunks]

## Generate the Embeddings

embeddings=embedding_manager.generate_embeddings(texts)

##store int he vector dtaabase
vectorstore.add_documents(chunks,embeddings)
# Out:
# Generating embeddings for 60 texts...
# Batches: 100%|██████████| 2/2 [00:00<00:00,  2.02it/s]
# Generated embeddings with shape: (60, 384)
# Adding 60 documents to vector store...
# Successfully added 60 documents to vector store
# Total documents in collection: 60

# %%
class RAGRetriever:
    """Handles query-based retrieval from the vector store"""
    
    def __init__(self, vector_store: VectorStore, embedding_manager: EmbeddingManager):
        """
        Initialize the retriever
        
        Args:
            vector_store: Vector store containing document embeddings
            embedding_manager: Manager for generating query embeddings
        """
        self.vector_store = vector_store
        self.embedding_manager = embedding_manager

    def retrieve(self, query: str, top_k: int = 5, score_threshold: float = 0.0) -> List[Dict[str, Any]]:
        """
        Retrieve relevant documents for a query
        
        Args:
            query: The search query
            top_k: Number of top results to return
            score_threshold: Minimum similarity score threshold
            
        Returns:
            List of dictionaries containing retrieved documents and metadata
        """
        print(f"Retrieving documents for query: '{query}'")
        print(f"Top K: {top_k}, Score threshold: {score_threshold}")
        
        # Generate query embedding
        query_embedding = self.embedding_manager.generate_embeddings([query])[0]
        
        # Search in vector store
        try:
            results = self.vector_store.collection.query(
                query_embeddings=[query_embedding.tolist()],
                n_results=top_k
            )
            
            # Process results
            retrieved_docs = []
            
            if results['documents'] and results['documents'][0]:
                documents = results['documents'][0]
                metadatas = results['metadatas'][0]
                distances = results['distances'][0]
                ids = results['ids'][0]
                
                for i, (doc_id, document, metadata, distance) in enumerate(zip(ids, documents, metadatas, distances)):
                    # Convert distance to similarity score (ChromaDB uses cosine distance)
                    similarity_score = 1 - distance
                    
                    if similarity_score >= score_threshold:
                        retrieved_docs.append({
                            'id': doc_id,
                            'content': document,
                            'metadata': metadata,
                            'similarity_score': similarity_score,
                            'distance': distance,
                            'rank': i + 1
                        })
                
                print(f"Retrieved {len(retrieved_docs)} documents (after filtering)")
            else:
                print("No documents found")
            
            return retrieved_docs
            
        except Exception as e:
            print(f"Error during retrieval: {e}")
            return []

rag_retriever=RAGRetriever(vectorstore,embedding_manager)

# %%
rag_retriever

# %%
rag_retriever.retrieve("SOFTWARE & HARDWARE REQUIREMENTS")
# Out:
# Retrieving documents for query: 'SOFTWARE & HARDWARE REQUIREMENTS'
# Top K: 5, Score threshold: 0.0
# Generating embeddings for 1 texts...
# Batches: 100%|██████████| 1/1 [00:00<00:00, 16.77it/s]
# Generated embeddings with shape: (1, 384)
# Retrieved 4 documents (after filtering)
# [{'id': 'doc_d3e41a19_46',
#   'content': '5.1  Software Requirements',
#   'metadata': {'author': 'Aarzu Hooda',
#    'producer': 'Microsoft® Word 2021',
#    'total_pages': 4,
#    'page': 2,
#    'creator': 'Microsoft® Word 2021',
#    'moddate': '2025-09-08T13:55:43+05:30',
#    'file_type': 'pdf',
#    'source_file': 'Synopsis.pdf',
#    'content_length': 26,
#    'source': '..\\data\\pdf\\Synopsis.pdf',
#    'creationdate': '2025-09-08T13:55:43+05:30',
#    'doc_index': 46,
#    'page_label': '3'},
#   'similarity_score': 0.3086581826210022,
#   'distance': 0.6913418173789978,
#   'rank': 1},
#  {'id': 'doc_8fb9007f_45',
#   'content': 'Training → Performance Comparison → Final Evaluation. \n5. SOFTWARE & HARDWARE REQUIREMENTS',
#   'metadata': {'source_file': 'Synopsis.pdf',
#    'doc_index': 45,
#    'author': 'Aarzu Hooda',
#    'page': 2,
#    'page_label': '3',
#    'moddate': '2025-09-08T13:55:43+05:30',
#    'producer': 'Microsoft® Word 2021',
#    'creationdate': '2025-09-08T13:55:43+05:30',
#    'total_pages': 4,
#    'content_length': 90,
#    'file_type': 'pdf',
#    'creator': 'Microsoft® Word 2021',
#    'source': '..\\data\\pdf\\Synopsis.pdf'},
#   'similarity_score': 0.24177849292755127,
#   'distance': 0.7582215070724487,
#   'rank': 2},
#  {'id': 'doc_44ad17e5_54',
#   'content': '5.2  Hardware Requirements \n• Processor: AMD Ryzen 7 or higher (multi-core recommended).',
#   'metadata': {'moddate': '2025-09-08T13:55:43+05:30',
#    'creationdate': '2025-09-08T13:55:43+05:30',
#    'page': 2,
#    'source': '..\\data\\pdf\\Synopsis.pdf',
#    'author': 'Aarzu Hooda',
#    'page_label': '3',
#    'file_type': 'pdf',
#    'doc_index': 54,
#    'creator': 'Microsoft® Word 2021',
#    'content_length': 88,
#    'total_pages': 4,
#    'source_file': 'Synopsis.pdf',
#    'producer': 'Microsoft® Word 2021'},
#   'similarity_score': 0.22153735160827637,
#   'distance': 0.7784626483917236,
#   'rank': 3},
#  {'id': 'doc_503bcc5c_55',
#   'content': '• RAM: Minimum 8 GB (16 GB preferred for faster simulations and ML training).',
#   'metadata': {'producer': 'Microsoft® Word 2021',
#    'content_length': 77,
#    'page_label': '3',
#    'page': 2,
#    'total_pages': 4,
#    'source': '..\\data\\pdf\\Synopsis.pdf',
#    'file_type': 'pdf',
#    'author': 'Aarzu Hooda',
#    'creationdate': '2025-09-08T13:55:43+05:30',
#    'doc_index': 55,
#    'moddate': '2025-09-08T13:55:43+05:30',
#    'creator': 'Microsoft® Word 2021',
#    'source_file': 'Synopsis.pdf'},
#   'similarity_score': 0.07731568813323975,
#   'distance': 0.9226843118667603,
#   'rank': 4}]
